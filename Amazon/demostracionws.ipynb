# %% [markdown]
# Si deseas crear un servicio utilizando el web scraping, podrías enfrentarte a bloqueos de IP y a la administración de proxies. Es bueno conocer las tecnologías y procesos subyacentes, pero para el scraping en masa, que problemas podemos tener y como solucionarlos.

# %%
#No te olvides de instalar bs4
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\tuka3\onedrive\escritorio\upgrade\mi_entorno\lib\site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tuka3\onedrive\escritorio\upgrade\mi_entorno\lib\site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %% [markdown]
# Creación de un User-Agent
#
# Muchos sitios web tienen ciertos protocolos para bloquear a los robots que acceden a los datos. Por lo tanto, para extraer datos de un script, necesitamos crear un User-Agent. El User-Agent es básicamente una cadena que le dice al servidor sobre el tipo de host que envía la solicitud.

# %%
usuario_fake = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
            'Accept-Language': 'es-ES, es;q=0.5'})

""" Hay un campo extra en ENCABEZADOS llamado "Accept-Language", que traduce la página web a español, si es necesario. """
# Out:
# ' Hay un campo extra en ENCABEZADOS llamado "Accept-Language", que traduce la página web a español, si es necesario. '

# %% [markdown]
# Una página web se accede por su URL (Uniform Resource Locator). Con la ayuda de la URL, enviaremos la solicitud a la página web para acceder a sus datos.

# %%
import requests
import bs4 
import pandas as pd

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\tuka3\onedrive\escritorio\upgrade\mi_entorno\lib\site-packages (5.2.2)

# %%
URL = "https://www.amazon.com/ZOTAC-Graphics-IceStorm-Advanced-ZT-A30900J-10P/dp/B08ZL6XD9H/"
pagina_web = requests.get(URL, headers=usuario_fake)

# %%
sopa = bs4.BeautifulSoup(pagina_web.content,'lxml')

# %% [markdown]
# ### sacando el titulo ( ejemplo )

# %%
title = sopa.find("span", attrs={"id":'productTitle'})
title_value = title.string
print(title_value.strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 title = sopa.find("span", attrs={"id":'productTitle'})
# ----> 2 title_value = title.string
#       3 print(title_value.strip())
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %% [markdown]
# ### Creando un ejemplo completo de un producto

# %%
from bs4 import BeautifulSoup
import requests

def get_title(soup):
	try:
		title = soup.find("span", attrs={"id":'productTitle'})
		title_value = title.string
		title_string = title_value.strip()
	except AttributeError:
		title_string = ""	
	return title_string

def get_price(soup):
	try:
		price = soup.find("span", attrs={'class':'a-offscreen'}).text.replace(',', '')
	except AttributeError:
		price = ""	
	return price

def get_rating(soup):
	try:
		rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
	except AttributeError:
		try:
			rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
		except:
			rating = ""	
	return rating

def get_review_count(soup):
	try:
		review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
	except AttributeError:
		review_count = ""	
	return review_count

def get_availability(soup):
	try:
		available = soup.find("div", attrs={'id':'availability'})
		available = available.find("span").string.strip()
	except AttributeError:
		available = ""	
	return available	

if __name__ == '__main__':

	HEADERS = ({'User-Agent':
	            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
	            'Accept-Language': 'en-US, en;q=0.5'})

	URL = "https://www.amazon.com/ZOTAC-Graphics-IceStorm-Advanced-ZT-A30900J-10P/dp/B08ZL6XD9H/"
	webpage = requests.get(URL, headers=HEADERS)

	soup = BeautifulSoup(webpage.content, "lxml")

	print("Product Title =", get_title(soup))
	print("Product Price =", get_price(soup))
	print("Product Rating =", get_rating(soup))
	print("Number of Product Reviews =", get_review_count(soup))
	print("Availability =", get_availability(soup))
	print()
	print()
# Out:
# Product Title = ZOTAC Gaming GeForce RTX™ 3090 Trinity OC 24GB GDDR6X 384-bit 19.5 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, Spectra 2.0 RGB Lighting, ZT-A30900J-10P
# Product Price = $1329.95
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 318 ratings
# Availability = Only 1 left in stock - order soon

# %% [markdown]
# ### Creando ejemplo con búsqueda

# %%
from bs4 import BeautifulSoup
import requests
import csv

def get_title(soup):
    try:
        title = soup.find("span", attrs={"id":'productTitle'}).string.strip()
    except AttributeError:
        return ""    
    return title

def get_price(soup):
    try:
        price = soup.find("span", attrs={'class':'a-offscreen'}).string.strip()
    except AttributeError:
        try:
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
        except:		
            return ""  
    return price

def get_rating(soup):
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            return ""
    return rating

def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
    except AttributeError:
        return ""
    return review_count

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'}).find("span").string.strip()
    except AttributeError:
        return "Not Available"
    return available

def main():
    HEADERS = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36', 'Accept-Language': 'en-US'}
    URL = input("Enter the Amazon Product Url- ") #Código para que sea también desde la consola
    webpage = requests.get(URL, headers=HEADERS)
    soup = BeautifulSoup(webpage.content, "lxml")

    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
    links_list = [link.get('href') for link in links]


    with open('amazon_product.csv', 'w', encoding="utf-8-sig") as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerow(['Title', 'Price', 'Rating', 'ReviewCount', 'Availability'])

        for link in links_list:
            new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
            new_soup = BeautifulSoup(new_webpage.content, "lxml")

            title = get_title(new_soup)
            price = get_price(new_soup)
            rating = get_rating(new_soup)
            review_count = get_review_count(new_soup)
            availability = get_availability(new_soup)

            print("Product Title =", title)
            print("Product Price =", price)
            print("Product Rating =", rating)
            print("Number of Product Reviews =", review_count)
            print("Availability =", availability)
            print('\n')

            # Escribe la información del producto en el archivo CSV.
            csv_writer.writerow([title, price, rating, review_count, availability])

if __name__ == '__main__':
    main()
# Out:
# Product Title = maxsun AMD Radeon RX 550 4GB GDDR5 ITX Computer PC Gaming Video Graphics Card GPU 128-Bit DirectX 12 PCI Express X16 3.0 DVI-D Dual Link, HDMI, DisplayPort
# Product Price = $109.99
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 984 ratings
# Availability = In Stock
#
#
# Product Title = GPVHOSO GeForce GT 1030 GDDR5 2GB 64 Bit DVI-D HDMI Output Graphics Card Computer, Video Card for PC Gaming
# Product Price = $99.98
# Product Rating = 3.5 out of 5 stars
# Number of Product Reviews = 2 ratings
# Availability = Only 7 left in stock - order soon
#
#
# Product Title = MSI Gaming GeForce RTX 3060 12GB 15 Gbps GDRR6 192-Bit HDMI/DP PCIe 4 Torx Twin Fan Ampere OC Graphics Card (Ventus 2X 12G OC)
# Product Price = $279.99
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 1,407 ratings
# Availability = In Stock
#
#
# Product Title = MSI Gaming GeForce RTX 3050 8GB GDRR6 128-Bit HDMI/DP PCIe 4 Torx Twin Fans Ampere OC Graphics Card (RTX 3050 Ventus 2X 8G OC)
# Product Price = $242.99
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 624 ratings
# Availability = In Stock
#
#
# Product Title = AISURIX Radeon RX 580 Graphic Cards, 2048SP, Real 8GB, GDDR5, 256 Bit, Pc Gaming Radeon Video Card for AMD, 2XDP, HDMI, PCI Express 3.0 with Freeze Fan Stop for Desktop Computer Gaming Gpu
# Product Price = $109.99
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 418 ratings
# Availability = In Stock
#
#
# Product Title = maxsun AMD Radeon RX 550 4GB GDDR5 ITX Computer PC Gaming Video Graphics Card GPU 128-Bit DirectX 12 PCI Express X16 3.0 DVI-D Dual Link, HDMI, DisplayPort
# Product Price = $109.99
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 984 ratings
# Availability = In Stock
#
#
# Product Title = AISURIX Radeon RX 5500 XT 8gb GDDR6 Graphics Card,128 Bit, 3XDP, HDMI, PCI Express 4.0X8, 8pin with Fan Intelligent System,Gaming PC Computer Video Cards with 3X DisplayPort +1X HDMI (Style 1)
# Product Price = $139.99
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 70 ratings
# Availability = In Stock
#
#
# Product Title = AISURIX Radeon RX 580 Graphic Cards, 2048SP, Real 8GB, GDDR5, 256 Bit, Pc Gaming Radeon Video Card for AMD, 2XDP, HDMI, PCI Express 3.0 with Freeze Fan Stop for Desktop Computer Gaming Gpu
# Product Price = $109.99
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 418 ratings
# Availability = In Stock
#
#
# Product Title = iHTP 5V ARGB Graphics Card GPU Brace Graphics Card Holder for ATX/MATX/ITX, Handscrew Adjust Height with Dual Support, Stronger Magnet Base Can Support White
# Product Price = $21.97
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 24 ratings
# Availability = In Stock
#
#
# Product Title = ZOTAC Gaming GeForce RTX 3060 Twin Edge OC 12GB GDDR6 192-bit 15 Gbps PCIE 4.0 Graphics Card, IceStorm 2.0 Cooling, Active Fan Control, Freeze Fan Stop ZT-A30600H-10M
# Product Price = $289.99
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 2,899 ratings
# Availability = In Stock
#
#
# Product Title = ZOTAC Gaming GeForce RTX 3050 Twin Edge OC 8GB GDDR6 128-bit 14 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, Freeze Fan Stop, Active Fan Control, ZT-A30500H-10M
# Product Price = $269.55
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 614 ratings
# Availability = In Stock
#
#
# Product Title = 51RISC RX 5500 XT Graphics Card, 8GB GDDR6 128bit PCIe 4.0 HDMI DisplayPort Gaming Video Card for Desktop (Radeon RX 5500 XT)
# Product Price = $135.99
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 24 ratings
# Availability = In Stock
#
#
# Product Title = GIGABYTE GeForce RTX 3070 Gaming OC 8G (REV2.0) Graphics Card, 3X WINDFORCE Fans, LHR, 8GB 256-bit GDDR6, GV-N3070GAMING OC-8GD Video Card
# Product Price = $491.12
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 669 ratings
# Availability = Only 8 left in stock - order soon
#
#
# Product Title = GIGABYTE GeForce RTX 3060 Gaming OC 12G (REV2.0) Graphics Card, 3X WINDFORCE Fans, 12GB 192-bit GDDR6, GV-N3060GAMING OC-12GD Video Card
# Product Price = $309.99
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 1,328 ratings
# Availability = In Stock
#
#
# Product Title = ZOTAC GeForce GTX 1660 Super 6GB GDDR6 192-bit Gaming Graphics Card, Super Compact, ZT-T16620F-10L
# Product Price = $283.46
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 2,538 ratings
# Availability = Only 18 left in stock - order soon
#
#
# Product Title = AISURIX Radeon RX 5500 XT 8gb GDDR6 Graphics Card,128 Bit, 3XDP, HDMI, PCI Express 4.0X8, 8pin with Fan Intelligent System,Gaming PC Computer Video Cards with 3X DisplayPort +1X HDMI (Style 1)
# Product Price = $139.99
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 70 ratings
# Availability = In Stock
#
#
# Product Title = ZOTAC GAMING GeForce RTX™ 3060 AMP White Edition 12GB GDDR6 192-bit 15 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Cooling, Active Fan Control, Freeze Fan Stop ZT-A30600F-10P
# Product Price = $369.99
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 278 ratings
# Availability = Only 5 left in stock - order soon
#
#
# Product Title = XFX Speedster SWFT309 Radeon RX 6700 Gaming Graphics Card with 10GB GDDR6 HDMI 3xDP, AMD RDNA 2 RX-67XLKWFDV
# Product Price = $278.50
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 6,128 ratings
# Availability =
#
#
# Product Title = PowerColor Fighter AMD Radeon RX 6600 Graphics Card with 8GB GDDR6 Memory
# Product Price = $199.99
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 706 ratings
# Availability = In Stock
#
#
# Product Title = ZOTAC Gaming GeForce GTX 1650 AMP CORE 4GB GDDR6 128-bit Gaming Graphics Card, Super Compact, ZT-T16520J-10L
# Product Price = $169.99
# Product Rating = 4.9 out of 5 stars
# Number of Product Reviews = 22 ratings
# Availability = In Stock
#
#
# Product Title = AISURIX Radeon RX 580 Graphic Cards, 2048SP, Real 8GB, GDDR5, 256 Bit, Pc Gaming Radeon Video Card for AMD, 2XDP, HDMI, PCI Express 3.0 with Freeze Fan Stop for Desktop Computer Gaming Gpu
# Product Price = $109.99
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 418 ratings
# Availability = In Stock
#
#
# Product Title = MSI Gaming GeForce RTX 3060 12GB 15 Gbps GDRR6 192-Bit HDMI/DP PCIe 4 Torx Triple Fan Ampere OC Graphics Card (RTX 3060 Ventus 3X 12G OC)
# Product Price = $289.99
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 779 ratings
# Availability = Only 18 left in stock - order soon
#
#
# Product Title = ZOTAC Gaming GeForce RTX™ 3060 Ti Twin Edge OC LHR 8GB GDDR6 256-bit 14 Gbps PCIE 4.0 Graphics Card, IceStorm 2.0 Advanced Cooling, Active Fan Control, Freeze Fan Stop ZT-A30610H-10MLHR
# Product Price = $332.99
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 1,368 ratings
# Availability = In Stock
#
#
# Product Title = maxsun AMD Radeon RX 580 8GB 2048SP GDDR5 Computer Video Graphics Card GPU for PC Gaming 256-Bit DirectX 12 DVI, HDMI, DisplayPort Multi Monitors Extend
# Product Price = $118.99
# Product Rating = 3.7 out of 5 stars
# Number of Product Reviews = 13 ratings
# Availability = In Stock
#
#
# Product Title = SRhonyra Radeon RX 580 8GB GDDR5 Graphics Card for Gaming PC Video Card 2048SP 256-Bit PCIe 3.0 x16 6-Pin Connector 2 Cooling Fan Desktop Computer Gaming GPU with HDMI, DisplayPort & DVI Ports
# Product Price = $89.99
# Product Rating = Previous page of related Sponsored Products
# Number of Product Reviews =
# Availability = Only 15 left in stock - order soon
#
#
# Product Title = GAMEMAX 850W Power Supply, Fully Modular, 80 Plus Gold, ARGB SYNC with Motherboard, RGB-850 Pro
# Product Price = $129.99
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 5,827 ratings
# Availability = In Stock

# %%
import pandas as pd
graficas = pd.read_csv('amazon_product.csv')

# %%
graficas
# Out:
#                                                 Title    Price  \
# 0   maxsun AMD Radeon RX 550 4GB GDDR5 ITX Compute...  $109.99
# 1   GPVHOSO GeForce GT 1030 GDDR5 2GB 64 Bit DVI-D...   $99.98
# 2   MSI Gaming GeForce RTX 3060 12GB 15 Gbps GDRR6...  $279.99
# 3   MSI Gaming GeForce RTX 3050 8GB GDRR6 128-Bit ...  $242.99
# 4   AISURIX Radeon RX 580 Graphic Cards, 2048SP, R...  $109.99
# 5   maxsun AMD Radeon RX 550 4GB GDDR5 ITX Compute...  $109.99
# 6   AISURIX Radeon RX 5500 XT 8gb GDDR6 Graphics C...  $139.99
# 7   AISURIX Radeon RX 580 Graphic Cards, 2048SP, R...  $109.99
# 8   iHTP 5V ARGB Graphics Card GPU Brace Graphics ...   $21.97
# 9   ZOTAC Gaming GeForce RTX 3060 Twin Edge OC 12G...  $289.99
# 10  ZOTAC Gaming GeForce RTX 3050 Twin Edge OC 8GB...  $269.55
# 11  51RISC RX 5500 XT Graphics Card, 8GB GDDR6 128...  $135.99
# 12  GIGABYTE GeForce RTX 3070 Gaming OC 8G (REV2.0...  $491.12
# 13  GIGABYTE GeForce RTX 3060 Gaming OC 12G (REV2....  $309.99
# 14  ZOTAC GeForce GTX 1660 Super 6GB GDDR6 192-bit...  $283.46
# 15  AISURIX Radeon RX 5500 XT 8gb GDDR6 Graphics C...  $139.99
# 16  ZOTAC GAMING GeForce RTX™ 3060 AMP White Editi...  $369.99
# 17  XFX Speedster SWFT309 Radeon RX 6700 Gaming Gr...  $278.50
# 18  PowerColor Fighter AMD Radeon RX 6600 Graphics...  $199.99
# 19  ZOTAC Gaming GeForce GTX 1650 AMP CORE 4GB GDD...  $169.99
# 20  AISURIX Radeon RX 580 Graphic Cards, 2048SP, R...  $109.99
# 21  MSI Gaming GeForce RTX 3060 12GB 15 Gbps GDRR6...  $289.99
# 22  ZOTAC Gaming GeForce RTX™ 3060 Ti Twin Edge OC...  $332.99
# 23  maxsun AMD Radeon RX 580 8GB 2048SP GDDR5 Comp...  $118.99
# 24  SRhonyra Radeon RX 580 8GB GDDR5 Graphics Card...   $89.99
# 25  GAMEMAX 850W Power Supply, Fully Modular, 80 P...  $129.99
#
#                                          Rating    ReviewCount  \
# 0                            4.2 out of 5 stars    984 ratings
# 1                            3.5 out of 5 stars      2 ratings
# 2                            4.7 out of 5 stars  1,407 ratings
# 3                            4.6 out of 5 stars    624 ratings
# 4                            4.4 out of 5 stars    418 ratings
# 5                            4.2 out of 5 stars    984 ratings
# 6                            4.2 out of 5 stars     70 ratings
# 7                            4.4 out of 5 stars    418 ratings
# 8                            4.2 out of 5 stars     24 ratings
# 9                            4.7 out of 5 stars  2,899 ratings
# 10                           4.6 out of 5 stars    614 ratings
# 11                           4.2 out of 5 stars     24 ratings
# 12                           4.7 out of 5 stars    669 ratings
# 13                           4.8 out of 5 stars  1,328 ratings
# 14                           4.7 out of 5 stars  2,538 ratings
# 15                           4.2 out of 5 stars     70 ratings
# 16                           4.7 out of 5 stars    278 ratings
# 17                           4.5 out of 5 stars  6,128 ratings
# 18                           4.5 out of 5 stars    706 ratings
# 19                           4.9 out of 5 stars     22 ratings
# 20                           4.4 out of 5 stars    418 ratings
# 21                           4.7 out of 5 stars    779 ratings
# 22                           4.6 out of 5 stars  1,368 ratings
# 23                           3.7 out of 5 stars     13 ratings
# 24  Previous page of related Sponsored Products            NaN
# 25                           4.5 out of 5 stars  5,827 ratings
#
#                           Availability
# 0                             In Stock
# 1    Only 7 left in stock - order soon
# 2                             In Stock
# 3                             In Stock
# 4                             In Stock
# 5                             In Stock
# 6                             In Stock
# 7                             In Stock
# 8                             In Stock
# 9                             In Stock
# 10                            In Stock
# 11                            In Stock
# 12   Only 8 left in stock - order soon
# 13                            In Stock
# 14  Only 18 left in stock - order soon
# 15                            In Stock
# 16   Only 5 left in stock - order soon
# 17                                 NaN
# 18                            In Stock
# 19                            In Stock
# 20                            In Stock
# 21  Only 18 left in stock - order soon
# 22                            In Stock
# 23                            In Stock
# 24  Only 15 left in stock - order soon
# 25                            In Stock
